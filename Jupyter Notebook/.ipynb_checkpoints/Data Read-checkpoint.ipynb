# %%
# load dependencies
from matplotlib import pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
import scipy.stats as st
import seaborn as sns

# %%
# read in files
happiness_2018_index = pd.read_csv('../Data/happiness_index_2018.csv')
alcohol_consumption = pd.read_csv('../Data/alcohol_consumption.csv')
consumption_type = pd.read_csv('../Data/drinks_csv.csv')

# merge csv files
df = pd.merge(happiness_2018_index, alcohol_consumption, on='Country', how='outer')
df = pd.merge(df, consumption_type, on='Country', how='outer')


# check the file has been read in
df
# Out:
#      Overall rank                       Country  Score  GDP per capita  \
# 0             1.0                       Finland  7.632           1.305
# 1             2.0                        Norway  7.594           1.456
# 2             3.0                       Denmark  7.555           1.351
# 3             4.0                       Iceland  7.495           1.343
# 4             5.0                   Switzerland  7.487           1.420
# ..            ...                           ...    ...             ...
# 295           NaN             St. Kitts & Nevis    NaN             NaN
# 296           NaN  St. Vincent & The Grenadines    NaN             NaN
# 297           NaN           Sao Tome & Principe    NaN             NaN
# 298           NaN                     Swaziland    NaN             NaN
# 299           NaN                           Usa    NaN             NaN
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 295             NaN                      NaN                           NaN
# 296             NaN                      NaN                           NaN
# 297             NaN                      NaN                           NaN
# 298             NaN                      NaN                           NaN
# 299             NaN                      NaN                           NaN
#
#      Generosity  Perceptions of corruption Country Code  ...   2000   2005  \
# 0         0.202                      0.393          FIN  ...  11.69  13.11
# 1         0.286                      0.340          NOR  ...   7.95   8.87
# 2         0.284                      0.408          DNK  ...  12.67  12.29
# 3         0.353                      0.138          ISL  ...   7.03   7.74
# 4         0.256                      0.357          CHE  ...  12.49  11.64
# ..          ...                        ...          ...  ...    ...    ...
# 295         NaN                        NaN          NaN  ...    NaN    NaN
# 296         NaN                        NaN          NaN  ...    NaN    NaN
# 297         NaN                        NaN          NaN  ...    NaN    NaN
# 298         NaN                        NaN          NaN  ...    NaN    NaN
# 299         NaN                        NaN          NaN  ...    NaN    NaN
#
#       2010   2015   2018                           con  beer_servings  \
# 0    12.59  11.18  10.78                       finland          263.0
# 1     8.94   7.52   7.41                        norway          169.0
# 2    11.00  10.36  10.26                       denmark          224.0
# 3     7.50   8.74   9.12                       iceland          233.0
# 4    11.41  11.58  11.53                   switzerland          185.0
# ..     ...    ...    ...                           ...            ...
# 295    NaN    NaN    NaN             st. kitts & nevis          194.0
# 296    NaN    NaN    NaN  st. vincent & the grenadines          120.0
# 297    NaN    NaN    NaN           sao tome & principe           56.0
# 298    NaN    NaN    NaN                     swaziland           90.0
# 299    NaN    NaN    NaN                           usa          249.0
#
#     spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0             133.0           97.0                          10.0
# 1              71.0          129.0                           6.7
# 2              81.0          278.0                          10.4
# 3              61.0           78.0                           6.6
# 4             100.0          280.0                          10.2
# ..              ...            ...                           ...
# 295           205.0           32.0                           7.7
# 296           221.0           11.0                           6.3
# 297            38.0          140.0                           4.2
# 298             2.0            2.0                           4.7
# 299           158.0           84.0                           8.7
#
# [300 rows x 22 columns]

# %%
# clean dataframe with only the relevant data
df = df[['Country', 'Country Code', 'Score', 'GDP per capita',"Social support", 'Healthy life expectancy', "Freedom to make life choices",
         'Generosity', 'Perceptions of corruption','2018', 'beer_servings', 'spirit_servings', 'wine_servings']]

# check dataframe for any errors
df = df.dropna()

# rename columns

df =df.rename(columns={"Country Code": "con_code", 
                       "GDP per capita": "GDP", 
                       "Social support": "social",
                       "Healthy life expectancy": "life_expectancy",
                       "Freedom to make life choices": "freedom",
                       'Perceptions of corruption': "corruption",
                       "2018": "alcohol_consumption"
                      })

df
# Out:
#                       Country con_code  Score    GDP  social  life_expectancy  \
# 0                     Finland      FIN  7.632  1.305   1.592            0.874
# 1                      Norway      NOR  7.594  1.456   1.582            0.861
# 2                     Denmark      DNK  7.555  1.351   1.590            0.868
# 3                     Iceland      ISL  7.495  1.343   1.644            0.914
# 4                 Switzerland      CHE  7.487  1.420   1.549            0.927
# ..                        ...      ...    ...    ...     ...              ...
# 148                   Liberia      LBR  3.495  0.076   0.858            0.267
# 150                    Rwanda      RWA  3.408  0.332   0.896            0.400
# 152                  Tanzania      TZA  3.303  0.455   0.991            0.381
# 154  Central African Republic      CAF  3.083  0.024   0.000            0.010
# 155                   Burundi      BDI  2.905  0.091   0.627            0.145
#
#      freedom  Generosity  corruption  alcohol_consumption  beer_servings  \
# 0      0.681       0.202       0.393                10.78          263.0
# 1      0.686       0.286       0.340                 7.41          169.0
# 2      0.683       0.284       0.408                10.26          224.0
# 3      0.677       0.353       0.138                 9.12          233.0
# 4      0.660       0.256       0.357                11.53          185.0
# ..       ...         ...         ...                  ...            ...
# 148    0.419       0.206       0.030                 6.12           19.0
# 150    0.636       0.200       0.444                 8.95           43.0
# 152    0.481       0.270       0.097                11.27           36.0
# 154    0.305       0.218       0.038                 2.38           17.0
# 155    0.065       0.149       0.076                 7.19           88.0
#
#      spirit_servings  wine_servings
# 0              133.0           97.0
# 1               71.0          129.0
# 2               81.0          278.0
# 3               61.0           78.0
# 4              100.0          280.0
# ..               ...            ...
# 148            152.0            2.0
# 150              2.0            0.0
# 152              6.0            1.0
# 154              2.0            1.0
# 155              0.0            0.0
#
# [132 rows x 13 columns]

# %%
# data check to see if this is an interesting enough correlation to explore
alcohol_c = df["alcohol_consumption"]
score = df['Score']

# create and format plot
plt.scatter(alcohol_c, score, marker="o", facecolors="red", edgecolors="black")

# show plot
plt.show()
plt.tight_layout()

# %%
# calculating correlation score

corr = st.pearsonr(alcohol_c,score)

corr
# Out:
# (0.3767996697635171, 8.460474354828837e-06)

# %%
df.describe()
# Out:
#             Score         GDP      social  life_expectancy     freedom  \
# count  132.000000  132.000000  132.000000       132.000000  132.000000
# mean     5.418758    0.881833    1.227333         0.596636    0.468697
# std      1.136180    0.384889    0.300493         0.249090    0.160986
# min      2.905000    0.000000    0.000000         0.000000    0.000000
# 25%      4.445500    0.601750    1.093000         0.413750    0.378750
# 50%      5.441000    0.950000    1.280000         0.655500    0.503500
# 75%      6.272500    1.179000    1.466500         0.782000    0.585250
# max      7.632000    1.649000    1.644000         1.008000    0.724000
#
#        Generosity  corruption  alcohol_consumption  beer_servings  \
# count  132.000000  132.000000           132.000000      132.00000
# mean     0.180667    0.116674             6.286636      116.50000
# std      0.101288    0.100331             4.120015      106.87265
# min      0.000000    0.000000             0.003000        0.00000
# 25%      0.109500    0.051750             2.457500       21.00000
# 50%      0.171500    0.082000             6.300000       78.50000
# 75%      0.239000    0.142500             9.542500      207.75000
# max      0.598000    0.457000            15.090000      376.00000
#
#        spirit_servings  wine_servings
# count       132.000000     132.000000
# mean         78.848485      58.393939
# std          78.284418      87.235380
# min           0.000000       0.000000
# 25%           6.000000       1.000000
# 50%          68.500000       9.000000
# 75%         119.000000      94.750000
# max         373.000000     370.000000

# %%
happyCountries = df[(df.Score > 7)]

happyCountries.describe()
# Out:
#            Score        GDP     social  life_expectancy    freedom  \
# count  13.000000  13.000000  13.000000        13.000000  13.000000
# mean    7.372538   1.317231   1.542154         0.885615   0.643538
# std     0.177600   0.107447   0.062055         0.028745   0.057912
# min     7.072000   1.010000   1.433000         0.817000   0.464000
# 25%     7.272000   1.305000   1.501000         0.874000   0.638000
# 50%     7.328000   1.341000   1.549000         0.888000   0.659000
# 75%     7.495000   1.355000   1.590000         0.910000   0.677000
# max     7.632000   1.456000   1.644000         0.927000   0.686000
#
#        Generosity  corruption  alcohol_consumption  beer_servings  \
# count   13.000000   13.000000            13.000000      13.000000
# mean     0.284077    0.284846             9.692308     217.538462
# std      0.064976    0.114106             1.928022      43.068967
# min      0.143000    0.082000             4.870000     149.000000
# 25%      0.256000    0.224000             8.940000     185.000000
# 50%      0.285000    0.302000            10.260000     224.000000
# 75%      0.333000    0.383000            10.780000     251.000000
# max      0.365000    0.408000            11.960000     279.000000
#
#        spirit_servings  wine_servings
# count        13.000000      13.000000
# mean         88.846154     163.230769
# std          24.354487      77.639288
# min          60.000000      11.000000
# 25%          72.000000     100.000000
# 50%          81.000000     186.000000
# 75%         100.000000     195.000000
# max         133.000000     280.000000

# %%
sadCountries = df[(df.Score < 4)]

sadCountries.describe()
# Out:
#            Score        GDP     social  life_expectancy    freedom  \
# count  15.000000  15.000000  15.000000        15.000000  15.000000
# mean    3.574467   0.350133   0.796400         0.262133   0.332133
# std     0.303548   0.254742   0.325643         0.117467   0.205329
# min     2.905000   0.024000   0.000000         0.010000   0.000000
# 25%     3.451500   0.222500   0.584000         0.229500   0.153000
# 50%     3.590000   0.332000   0.858000         0.267000   0.406000
# 75%     3.784500   0.406000   1.042500         0.343500   0.457500
# max     3.999000   1.017000   1.215000         0.417000   0.636000
#
#        Generosity  corruption  alcohol_consumption  beer_servings  \
# count   15.000000   15.000000            15.000000      15.000000
# mean     0.180200    0.100867             4.720667      54.600000
# std      0.082082    0.098754             3.093393      63.683144
# min      0.042000    0.030000             0.210000       0.000000
# 25%      0.140500    0.055000             2.420000      13.000000
# 50%      0.185000    0.092000             4.590000      36.000000
# 75%      0.208000    0.100000             6.765000      73.000000
# max      0.392000    0.444000            11.270000     217.000000
#
#        spirit_servings  wine_servings
# count        15.000000      15.000000
# mean         43.666667       7.666667
# std          87.346328      14.074631
# min           0.000000       0.000000
# 25%           2.000000       0.500000
# 50%          11.000000       1.000000
# 75%          32.000000       4.000000
# max         326.000000      45.000000

# %% [markdown]
# ### CREATE DATABASE CONNECTION

# %%
#create connection
import psycopg2

# %% [markdown]
# Load Data into Postgres

# %%
# create params_dic
param_dic = {
    "host"      : "",
    "database"  : "",
    "user"      : "",
    "password"  : ""
}

# %%
# set up connection
connect = "postgresql+psycopg2://%s:%s@%s:5432/%s" % (
    param_dic['user'],
    param_dic['password'],
    param_dic['host'],
    param_dic['database']
)

engine = create_engine(connect)

# %%
conn = engine.connect()

results = conn.execute('Select * from df')

# %%
all_countries = []
 
for country, con_code, score, gdp, social, health, freedom, generosity, corruption, alcohol, beer_servings, wine_servings, spirit_servings in results:
    print(country)
    countries_dict = {}
    countries_dict["Country"] = country
    countries_dict["Country Code"] = con_code
    countries_dict["Score"] = score
    countries_dict["GDP per capita"] = gdp
    countries_dict["Social support"] = social
    countries_dict["Health life expectancy"] = health
    countries_dict["Freedom to make life choices"] = freedom
    countries_dict["Generosity"] = generosity
    countries_dict["Perceptions of corruption"] = corruption
    countries_dict["Alcohol Consumption per Capita (liter)"] = alcohol
    countries_dict["beer_servings"] = beer_servings
    countries_dict["wine_servings"] = wine_servings
    countries_dict["spirit_servings"] = beer_servings
    all_countries.append(countries_dict)



print(all_countries)
# Out:
# Finland
# Norway
# Denmark
# Iceland
# Switzerland
# Netherlands
# Canada
# New Zealand
# Sweden
# Australia
# United Kingdom
# Austria
# Costa Rica
# Ireland
# Germany
# Belgium
# Luxembourg
# Israel
# Czech Republic
# Malta
# France
# Mexico
# Chile
# Panama
# Brazil
# Argentina
# Guatemala
# Uruguay
# Qatar
# Saudi Arabia
# Singapore
# Malaysia
# Spain
# Colombia
# El Salvador
# Nicaragua
# Poland
# Bahrain
# Uzbekistan
# Kuwait
# Thailand
# Italy
# Ecuador
# Belize
# Lithuania
# Slovenia
# Romania
# Latvia
# Japan
# Mauritius
# Jamaica
# Kazakhstan
# Cyprus
# Bolivia
# Estonia
# Paraguay
# Peru
# Moldova
# Turkmenistan
# Hungary
# Libya
# Philippines
# Honduras
# Belarus
# Turkey
# Pakistan
# Portugal
# Serbia
# Greece
# Lebanon
# Montenegro
# Croatia
# Dominican Republic
# Algeria
# Morocco
# China
# Azerbaijan
# Tajikistan
# Jordan
# Nigeria
# Mongolia
# Vietnam
# Indonesia
# Bhutan
# Somalia
# Cameroon
# Bulgaria
# Nepal
# Gabon
# South Africa
# Ghana
# Senegal
# Tunisia
# Albania
# Sierra Leone
# Bangladesh
# Sri Lanka
# Iraq
# Mali
# Namibia
# Cambodia
# Burkina Faso
# Mozambique
# Kenya
# Zambia
# Mauritania
# Ethiopia
# Georgia
# Armenia
# Myanmar
# Chad
# India
# Niger
# Uganda
# Benin
# Sudan
# Ukraine
# Togo
# Guinea
# Lesotho
# Angola
# Madagascar
# Zimbabwe
# Afghanistan
# Botswana
# Malawi
# Haiti
# Liberia
# Rwanda
# Tanzania
# Central African Republic
# Burundi
# [{'Country': 'Finland', 'Country Code': 'FIN', 'Score': 7.632000000000001, 'GDP per capita': 1.305, 'Social support': 1.5919999999999999, 'Health life expectancy': 0.8740000000000001, 'Freedom to make life choices': 0.6809999999999999, 'Generosity': 0.20199999999999999, 'Perceptions of corruption': 0.39299999999999996, 'Alcohol Consumption per Capita (liter)': 10.78, 'beer_servings': 263.0, 'wine_servings': 133.0, 'spirit_servings': 263.0}, {'Country': 'Norway', 'Country Code': 'NOR', 'Score': 7.593999999999999, 'GDP per capita': 1.456, 'Social support': 1.5819999999999999, 'Health life expectancy': 0.861, 'Freedom to make life choices': 0.6859999999999999, 'Generosity': 0.28600000000000003, 'Perceptions of corruption': 0.34, 'Alcohol Consumption per Capita (liter)': 7.41, 'beer_servings': 169.0, 'wine_servings': 71.0, 'spirit_servings': 169.0}, {'Country': 'Denmark', 'Country Code': 'DNK', 'Score': 7.555, 'GDP per capita': 1.351, 'Social support': 1.59, 'Health life expectancy': 0.868, 'Freedom to make life choices': 0.6829999999999999, 'Generosity': 0.284, 'Perceptions of corruption': 0.408, 'Alcohol Consumption per Capita (liter)': 10.26, 'beer_servings': 224.0, 'wine_servings': 81.0, 'spirit_servings': 224.0}, {'Country': 'Iceland', 'Country Code': 'ISL', 'Score': 7.495, 'GDP per capita': 1.3430000000000002, 'Social support': 1.6440000000000001, 'Health life expectancy': 0.914, 'Freedom to make life choices': 0.677, 'Generosity': 0.353, 'Perceptions of corruption': 0.138, 'Alcohol Consumption per Capita (liter)': 9.12, 'beer_servings': 233.0, 'wine_servings': 61.0, 'spirit_servings': 233.0}, {'Country': 'Switzerland', 'Country Code': 'CHE', 'Score': 7.487, 'GDP per capita': 1.42, 'Social support': 1.5490000000000002, 'Health life expectancy': 0.927, 'Freedom to make life choices': 0.66, 'Generosity': 0.256, 'Perceptions of corruption': 0.35700000000000004, 'Alcohol Consumption per Capita (liter)': 11.53, 'beer_servings': 185.0, 'wine_servings': 100.0, 'spirit_servings': 185.0}, {'Country': 'Netherlands', 'Country Code': 'NLD', 'Score': 7.441, 'GDP per capita': 1.361, 'Social support': 1.4880000000000002, 'Health life expectancy': 0.878, 'Freedom to make life choices': 0.638, 'Generosity': 0.33299999999999996, 'Perceptions of corruption': 0.295, 'Alcohol Consumption per Capita (liter)': 9.61, 'beer_servings': 251.0, 'wine_servings': 88.0, 'spirit_servings': 251.0}, {'Country': 'Canada', 'Country Code': 'CAN', 'Score': 7.327999999999999, 'GDP per capita': 1.33, 'Social support': 1.5319999999999998, 'Health life expectancy': 0.8959999999999999, 'Freedom to make life choices': 0.653, 'Generosity': 0.321, 'Perceptions of corruption': 0.29100000000000004, 'Alcohol Consumption per Capita (liter)': 8.94, 'beer_servings': 240.0, 'wine_servings': 122.0, 'spirit_servings': 240.0}, {'Country': 'New Zealand', 'Country Code': 'NZL', 'Score': 7.324, 'GDP per capita': 1.268, 'Social support': 1.601, 'Health life expectancy': 0.8759999999999999, 'Freedom to make life choices': 0.669, 'Generosity': 0.365, 'Perceptions of corruption': 0.389, 'Alcohol Consumption per Capita (liter)': 10.63, 'beer_servings': 203.0, 'wine_servings': 79.0, 'spirit_servings': 203.0}, {'Country': 'Sweden', 'Country Code': 'SWE', 'Score': 7.314, 'GDP per capita': 1.355, 'Social support': 1.501, 'Health life expectancy': 0.9129999999999999, 'Freedom to make life choices': 0.659, 'Generosity': 0.285, 'Perceptions of corruption': 0.38299999999999995, 'Alcohol Consumption per Capita (liter)': 8.93, 'beer_servings': 152.0, 'wine_servings': 60.0, 'spirit_servings': 152.0}, {'Country': 'Australia', 'Country Code': 'AUS', 'Score': 7.272, 'GDP per capita': 1.34, 'Social support': 1.5730000000000002, 'Health life expectancy': 0.91, 'Freedom to make life choices': 0.647, 'Generosity': 0.361, 'Perceptions of corruption': 0.302, 'Alcohol Consumption per Capita (liter)': 10.51, 'beer_servings': 261.0, 'wine_servings': 72.0, 'spirit_servings': 261.0}, {'Country': 'United Kingdom' ...

# %%
# def to_alchemy(df):
#     """
#     Using a dummy table to test this call library
#     """
# engine = create_engine(connect)
# df.to_sql(
#         'df', 
#         con=engine, 
#         index=False, 
#         if_exists='replace'
#     )
# print("to_sql() done (sqlalchemy)")
# Out:
# to_sql() done (sqlalchemy)

# %%
df.head()
